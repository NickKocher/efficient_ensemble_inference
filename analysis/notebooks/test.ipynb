# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

x = np.linspace(0, 10, 300)
y1 = np.log(x + 1) + 0.1
y2 = np.log(x + 1) + 0.12
y3 = np.log(x + 1) + 0.14

fig, ax = plt.subplots()

ax.plot(x, y1, label="Line 1")
ax.plot(x, y2, label="Line 2")
ax.plot(x, y3, label="Line 3")
ax.legend()

# Create inset
axins = inset_axes(ax, width="30%", height="30%", loc="upper left")
axins.plot(x, y1)
axins.plot(x, y2)
axins.plot(x, y3)

# Limits where differences are small
x1, x2 = 8, 10
axins.set_xlim(x1, x2)
axins.set_ylim( np.min([y1[-1], y2[-1], y3[-1]]) - 0.02,
                np.max([y1[-1], y2[-1], y3[-1]]) + 0.02)

mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 300)
y1 = np.log(x + 1) + 0.1
y2 = np.log(x + 1) + 0.12
y3 = np.log(x + 1) + 0.14

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(5,5),
                               gridspec_kw={'height_ratios':[1,1]})

# Upper axis (full range)
ax1.plot(x, y1)
ax1.plot(x, y2)
ax1.plot(x, y3)
ax1.set_ylim(0, 1.8)   # big range

# Lower axis (zoomed range)
ax2.plot(x, y1)
ax2.plot(x, y2)
ax2.plot(x, y3)
ax2.set_ylim(1.35, 1.45)  # zoom into small differences

# Hide spines between them
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.tick_params(labelbottom=False)

plt.show()

# %%
text1 = """167210 (952 (30.22 %) missing)
233214 (1530 (60.28 %) missing)
233215 (466 (18.63 %) missing)
359929 (311 (12.61 %) missing)
359930 (1524 (45.28 %) missing)
359931 (2047 (60.17 %) missing)
359932 (1058 (33.98 %) missing)
359933 (637 (22.54 %) missing)
359934 (1612 (48.94 %) missing)
359935 (769 (27.21 %) missing)
359939 (336 (13.24 %) missing)
359940 (370 (14.37 %) missing)
359941 (184 (7.15 %) missing)
359942 (246 (9.56 %) missing)
359944 (748 (24.59 %) missing)
359945 (994 (33.07 %) missing)
359948 (371 (14.02 %) missing)
359950 (1505 (45.69 %) missing)
359951 (1102 (35.80 %) missing)
360932 (708 (27.90 %) missing)
360933 (802 (32.05 %) missing)
360945 (544 (17.88 %) missing)
2073 (1192 (37.84 %) missing)
3945 (279 (10.84 %) missing)
7593 (248 (10.21 %) missing)
146818 (1800 (51.28 %) missing)
146820 (651 (23.64 %) missing)
167120 (476 (19.59 %) missing)
168350 (566 (21.39 %) missing)
168757 (1864 (55.98 %) missing)
168784 (1094 (35.13 %) missing)
168868 (532 (20.38 %) missing)
168909 (1232 (50.70 %) missing)
168910 (1024 (41.52 %) missing)
168911 (1152 (38.79 %) missing)
189354 (528 (20.80 %) missing)
189355 (675 (27.78 %) missing)
189356 (1224 (50.37 %) missing)
189922 (988 (38.93 %) missing)
190137 (1094 (34.73 %) missing)
190146 (1278 (38.80 %) missing)
190392 (897 (31.34 %) missing)
190410 (708 (27.13 %) missing)
190411 (388 (14.47 %) missing)
211979 (276 (10.87 %) missing)
211986 (545 (22.10 %) missing)
359953 (1581 (50.19 %) missing)
359958 (614 (19.27 %) missing)
359959 (695 (22.06 %) missing)
359960 (204 (6.79 %) missing)
359961 (1103 (35.02 %) missing)
359962 (288 (9.36 %) missing)
359963 (324 (11.18 %) missing)
359964 (499 (17.89 %) missing)
359965 (373 (12.71 %) missing)
359966 (1192 (45.05 %) missing)
359967 (1174 (44.98 %) missing)
359968 (122 (4.67 %) missing)
359971 (57 (2.31 %) missing)
359973 (840 (34.57 %) missing)
359974 (14 (0.53 %) missing)
359975 (581 (20.05 %) missing)
359977 (167 (6.58 %) missing)
359979 (960 (37.83 %) missing)
359980 (1417 (54.29 %) missing)
359981 (1380 (52.87 %) missing)
359982 (1162 (46.44 %) missing)
359983 (1470 (57.11 %) missing)
359984 (950 (39.09 %) missing)
359986 (1512 (62.22 %) missing)
359987 (523 (19.24 %) missing)
359988 (1304 (53.66 %) missing)
359989 (1400 (57.61 %) missing)
359991 (27 (1.11 %) missing)
359992 (1250 (48.56 %) missing)
359993 (35 (1.40 %) missing)
359994 (630 (25.93 %) missing)
360112 (674 (27.74 %) missing)
360113 (398 (16.14 %) missing)
360114 (593 (23.04 %) missing)
360975 (1344 (55.31 %) missing)
"""

# %%
text1_info = {}

for line in text1.strip().split("\n"):
    parts = line.split(" (")
    id_ = parts[0]
    missing_info = parts[1].rstrip(")")
    missing_count = int(missing_info.split(" ")[0])
    text1_info[id_] = missing_count

text2_info = {}
for line in text2.strip().split("\n"):
    parts = line.split(" (")
    id_ = parts[0]
    missing_info = parts[1].rstrip(")")
    missing_count = int(missing_info.split(" ")[0])
    text2_info[id_] = missing_count


differences = {}
for id_ in text1_info:
    missing1 = text1_info[id_]
    missing2 = text2_info.get(id_, 0)
    diff = missing1 - missing2
    differences[id_] = diff / missing1 * 100  # Percentage difference

# Sort based on the percentage difference
sorted_differences = dict(sorted(differences.items(), key=lambda item: item[1], reverse=True))
for id_, diff in sorted_differences.items():
    print(f"Task ID: {id_}, Reduction in Missing Values: {diff:.2f}%")
# Out:
# Task ID: 359933, Reduction in Missing Values: 100.00%
# Task ID: 359939, Reduction in Missing Values: 100.00%
# Task ID: 359940, Reduction in Missing Values: 100.00%
# Task ID: 359941, Reduction in Missing Values: 100.00%
# Task ID: 359942, Reduction in Missing Values: 100.00%
# Task ID: 359948, Reduction in Missing Values: 100.00%
# Task ID: 359969, Reduction in Missing Values: 100.00%
# Task ID: 359970, Reduction in Missing Values: 100.00%
# Task ID: 359935, Reduction in Missing Values: 99.87%
# Task ID: 359974, Reduction in Missing Values: 97.44%
# Task ID: 359971, Reduction in Missing Values: 88.97%
# Task ID: 359991, Reduction in Missing Values: 88.51%
# Task ID: 190411, Reduction in Missing Values: 79.38%
# Task ID: 233215, Reduction in Missing Values: 75.97%
# Task ID: 359993, Reduction in Missing Values: 75.69%
# Task ID: 360945, Reduction in Missing Values: 75.00%
# Task ID: 359968, Reduction in Missing Values: 74.26%
# Task ID: 359944, Reduction in Missing Values: 71.12%
# ...
