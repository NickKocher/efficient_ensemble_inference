# %%
import seaborn as sns

# %%
COLORS = {
    "blue":   "#3F6FAF",
    "orange": "#E0723C",
    "green":  "#57A567",
    "red":    "#C54650",
    "purple": "#885FBB",
    "teal":   "#4A9A9E",
}

# %%
sns.color_palette(list(COLORS.values()))
# Out:
# [(0.24705882352941178, 0.43529411764705883, 0.6862745098039216),
#  (0.8784313725490196, 0.4470588235294118, 0.23529411764705882),
#  (0.3411764705882353, 0.6470588235294118, 0.403921568627451),
#  (0.7725490196078432, 0.27450980392156865, 0.3137254901960784),
#  (0.5333333333333333, 0.37254901960784315, 0.7333333333333333),
#  (0.2901960784313726, 0.6039215686274509, 0.6196078431372549)]
